# %%
words = open('names.txt', 'r').read().splitlines()

# %%
import torch
print(np.array([[w for w in word] for word in words]).reshape(-1))
# Out:
# [['e', 'm', 'm', 'a'], ['o', 'l', 'i', 'v', 'i', 'a'], ['a', 'v', 'a'], ['i', 's', 'a', 'b', 'e', 'l', 'l', 'a'], ['s', 'o', 'p', 'h', 'i', 'a'], ['c', 'h', 'a', 'r', 'l', 'o', 't', 't', 'e'], ['m', 'i', 'a'], ['a', 'm', 'e', 'l', 'i', 'a'], ['h', 'a', 'r', 'p', 'e', 'r'], ['e', 'v', 'e', 'l', 'y', 'n'], ['a', 'b', 'i', 'g', 'a', 'i', 'l'], ['e', 'm', 'i', 'l', 'y'], ['e', 'l', 'i', 'z', 'a', 'b', 'e', 't', 'h'], ['m', 'i', 'l', 'a'], ['e', 'l', 'l', 'a'], ['a', 'v', 'e', 'r', 'y'], ['s', 'o', 'f', 'i', 'a'], ['c', 'a', 'm', 'i', 'l', 'a'], ['a', 'r', 'i', 'a'], ['s', 'c', 'a', 'r', 'l', 'e', 't', 't'], ['v', 'i', 'c', 't', 'o', 'r', 'i', 'a'], ['m', 'a', 'd', 'i', 's', 'o', 'n'], ['l', 'u', 'n', 'a'], ['g', 'r', 'a', 'c', 'e'], ['c', 'h', 'l', 'o', 'e'], ['p', 'e', 'n', 'e', 'l', 'o', 'p', 'e'], ['l', 'a', 'y', 'l', 'a'], ['r', 'i', 'l', 'e', 'y'], ['z', 'o', 'e', 'y'], ['n', 'o', 'r', 'a'], ['l', 'i', 'l', 'y'], ['e', 'l', 'e', 'a', 'n', 'o', 'r'], ['h', 'a', 'n', 'n', 'a', 'h'], [
# ...

# %%
dict = {}
for w in words:
    word = ['<S>'] + list(w) + ['<E>']
    for ch1, ch2 in zip(word, word[1:]):
        bigram = (ch1, ch2)
        dict[bigram] = dict.get(bigram, 0) + 1

# %%
sorted(dict.items(), key = lambda kv: -kv[1])
# Out:
# [(('n', '<E>'), 6763),
#  (('a', '<E>'), 6640),
#  (('a', 'n'), 5438),
#  (('<S>', 'a'), 4410),
#  (('e', '<E>'), 3983),
#  (('a', 'r'), 3264),
#  (('e', 'l'), 3248),
#  (('r', 'i'), 3033),
#  (('n', 'a'), 2977),
#  (('<S>', 'k'), 2963),
#  (('l', 'e'), 2921),
#  (('e', 'n'), 2675),
#  (('l', 'a'), 2623),
#  (('m', 'a'), 2590),
#  (('<S>', 'm'), 2538),
#  (('a', 'l'), 2528),
#  (('i', '<E>'), 2489),
#  (('l', 'i'), 2480),
#  (('i', 'a'), 2445),
#  (('<S>', 'j'), 2422),
#  (('o', 'n'), 2411),
#  (('h', '<E>'), 2409),
#  (('r', 'a'), 2356),
#  (('a', 'h'), 2332),
#  (('h', 'a'), 2244),
#  (('y', 'a'), 2143),
#  (('i', 'n'), 2126),
#  (('<S>', 's'), 2055),
#  (('a', 'y'), 2050),
#  (('y', '<E>'), 2007),
#  (('e', 'r'), 1958),
#  (('n', 'n'), 1906),
#  (('y', 'n'), 1826),
#  (('k', 'a'), 1731),
#  (('n', 'i'), 1725),
#  (('r', 'e'), 1697),
#  (('<S>', 'd'), 1690),
#  (('i', 'e'), 1653),
#  (('a', 'i'), 1650),
#  (('<S>', 'r'), 1639),
#  (('a', 'm'), 1634),
#  (('l', 'y'), 1588),
# ...
